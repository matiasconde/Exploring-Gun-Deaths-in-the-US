# %%
import csv

f = open("guns.csv","r")
csvreader = csv.reader(f)
data = list(csvreader)

data[:5]
# Out:
# [['',
#   'year',
#   'month',
#   'intent',
#   'police',
#   'sex',
#   'age',
#   'race',
#   'hispanic',
#   'place',
#   'education'],
#  ['1',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '4'],
#  ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'],
#  ['3',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]

# %%
headers = data[0]

data = data[1:]

data[:5]
# Out:
# [['1',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '34',
#   'Asian/Pacific Islander',
#   '100',
#   'Home',
#   '4'],
#  ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'],
#  ['3',
#   '2012',
#   '01',
#   'Suicide',
#   '0',
#   'M',
#   '60',
#   'White',
#   '100',
#   'Other specified',
#   '4'],
#  ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'],
#  ['5',
#   '2012',
#   '02',
#   'Suicide',
#   '0',
#   'M',
#   '31',
#   'White',
#   '100',
#   'Other specified',
#   '2']]

# %%
years = [row[1] for row in data]

year_counts = {}

for year in years:
    if year not in year_counts:
        year_counts[year] = 1
    if year in year_counts:
        year_counts[year] += 1
        
year_counts
# Out:
# {'2012': 33564, '2013': 33637, '2014': 33600}

# %%
import datetime

dates = [datetime.datetime(year=int(row[1]),month=int(row[2]),day=1) for row in data]

dates[:5]

date_counts = {}

for date in dates:
    if date not in date_counts:
        date_counts[date] = 1
    if date in date_counts:
        date_counts[date] += 1
        
date_counts
# Out:
# {datetime.datetime(2012, 1, 1, 0, 0): 2759,
#  datetime.datetime(2012, 2, 1, 0, 0): 2358,
#  datetime.datetime(2012, 3, 1, 0, 0): 2744,
#  datetime.datetime(2012, 4, 1, 0, 0): 2796,
#  datetime.datetime(2012, 5, 1, 0, 0): 3000,
#  datetime.datetime(2012, 6, 1, 0, 0): 2827,
#  datetime.datetime(2012, 7, 1, 0, 0): 3027,
#  datetime.datetime(2012, 8, 1, 0, 0): 2955,
#  datetime.datetime(2012, 9, 1, 0, 0): 2853,
#  datetime.datetime(2012, 10, 1, 0, 0): 2734,
#  datetime.datetime(2012, 11, 1, 0, 0): 2730,
#  datetime.datetime(2012, 12, 1, 0, 0): 2792,
#  datetime.datetime(2013, 1, 1, 0, 0): 2865,
#  datetime.datetime(2013, 2, 1, 0, 0): 2376,
#  datetime.datetime(2013, 3, 1, 0, 0): 2863,
#  datetime.datetime(2013, 4, 1, 0, 0): 2799,
#  datetime.datetime(2013, 5, 1, 0, 0): 2807,
#  datetime.datetime(2013, 6, 1, 0, 0): 2921,
#  datetime.datetime(2013, 7, 1, 0, 0): 3080,
#  datetime.datetime(2013, 8, 1, 0, 0): 2860,
#  datetime.datetime(2013, 9, 1, 0, 0): 2743,
# ...

# %%
sexs = [row[5] for row in data]

sex_counts = {}

for sex in sexs:
    if sex not in sex_counts:
        sex_counts[sex] = 1
    if sex in sex_counts:
        sex_counts[sex] += 1

sex_counts

races = [row[7] for row in data]

race_counts = {}

for race in races:
    if race not in race_counts:
        race_counts[race] = 1
    if race in race_counts:
        race_counts[race] += 1

race_counts
# Out:
# {'Asian/Pacific Islander': 1327,
#  'Black': 23297,
#  'Hispanic': 9023,
#  'Native American/Native Alaskan': 918,
#  'White': 66238}

# %% [markdown]
# ## First Analisys
#
# It seems that white people are the most killed people in US. But be careful because those are also the majority of people in US.

# %%
f = open("census.csv","r")
csvreader = csv.reader(f)
census = list(csvreader)

census
# Out:
# [['Id',
#   'Year',
#   'Id',
#   'Sex',
#   'Id',
#   'Hispanic Origin',
#   'Id',
#   'Id2',
#   'Geography',
#   'Total',
#   'Race Alone - White',
#   'Race Alone - Hispanic',
#   'Race Alone - Black or African American',
#   'Race Alone - American Indian and Alaska Native',
#   'Race Alone - Asian',
#   'Race Alone - Native Hawaiian and Other Pacific Islander',
#   'Two or More Races'],
#  ['cen42010',
#   'April 1, 2010 Census',
#   'totsex',
#   'Both Sexes',
#   'tothisp',
#   'Total',
#   '0100000US',
#   '',
#   'United States',
#   '308745538',
#   '197318956',
#   '44618105',
#   '40250635',
#   '3739506',
#   '15159516',
#   '674625',
#   '6984195']]

# %%
mappings = {"Asian/Pacific Islander":0,"Black":0,"Native American/Native Alaskan":0,"Hispanic":0,"White":0}

mappings["White"] += int(census[1][10])
mappings["Asian/Pacific Islander"] += int(census[1][14]) + int(census[1][15])
mappings["Black"] += int(census[1][12])
mappings["Native American/Native Alaskan"] += int(census[1][13])
mappings["Hispanic"] += int(census[1][11])

mappings
# Out:
# {'Asian/Pacific Islander': 15834141,
#  'Black': 40250635,
#  'Hispanic': 44618105,
#  'Native American/Native Alaskan': 3739506,
#  'White': 197318956}

# %%
race_per_hundredk = {}

for key in race_counts:
    race_per_hundredk[key] = race_counts[key]*100000/mappings[key]
    
print(race_per_hundredk)
# Out:
# {'Asian/Pacific Islander': 8.380625131480135, 'White': 33.568999827872595, 'Native American/Native Alaskan': 24.548697073891578, 'Black': 57.879832206373884, 'Hispanic': 20.222732453563413}

# %%
intents = [row[3] for row in data]
intents[:17]
# Out:
# ['Suicide',
#  'Suicide',
#  'Suicide',
#  'Suicide',
#  'Suicide',
#  'Suicide',
#  'Undetermined',
#  'Suicide',
#  'Accidental',
#  'Suicide',
#  'Suicide',
#  'Suicide',
#  'Suicide',
#  'Suicide',
#  'Homicide',
#  'Suicide',
#  'Suicide']

# %%
races = [row[7] for row in data]
races[:30]
# Out:
# ['Asian/Pacific Islander',
#  'White',
#  'White',
#  'White',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'Black',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'Native American/Native Alaskan',
#  'Asian/Pacific Islander',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'Black',
#  'White',
#  'White',
#  'White',
#  'Native American/Native Alaskan',
#  'White',
#  'White',
#  'White']

# %%
homicide_race_counts = {}

for i,v in enumerate(races):
    if intents[i] == "Homicide":
        if v not in homicide_race_counts:
            homicide_race_counts[v] = 1
        if v in homicide_race_counts:
            homicide_race_counts[v] += 1

homicide_race_counts
# Out:
# {'Asian/Pacific Islander': 560,
#  'Black': 19511,
#  'Hispanic': 5635,
#  'Native American/Native Alaskan': 327,
#  'White': 9148}

# %%
race_per_hundredk_homicide = {}

for key in homicide_race_counts:
    race_per_hundredk_homicide[key] = homicide_race_counts[key]*100000/mappings[key]
    
print(race_per_hundredk_homicide)
# Out:
# {'White': 4.636148591826119, 'Asian/Pacific Islander': 3.5366616982885275, 'Black': 48.47376942003524, 'Native American/Native Alaskan': 8.744470526320857, 'Hispanic': 12.62940234687242}

# %% [markdown]
# ## The conclusion is contundent
#
# The black people are almost the half of the death by homicide in the US.
